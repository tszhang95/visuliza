# %% [markdown]
# # cb6 PNSR

# %%
import csv
import pandas as pd
file1 = './csv_file/Jul22_LLF_lolv1_V13_10_cb6_good_PSNR.csv'
file2 = './csv_file/Jul26_LLF _lolv1 V13_11_cb6_PSNR.csv'
file3 = './csv_file/Jul27_LLF_lolv1_V13_11L2_cb6_PSNR.csv'
# file4 = './csv_file/Jul27_LLF_lolv1_V13_12_cb6_PSNR.csv'
file5 = './csv_file/Jul30_LLF_lolv1_V13_13_0_cb6_PSNR.csv'
file6 = './csv_file/Jul30_LLF_lolv1_V13_13_1_cb6_PSNR.csv'
file7 = './csv_file/Jul30_LLF_lolv1_V13_13_2_cb6_PSNR.csv'
file8 = './csv_file/Jul24_LLF_lolv1_V13_10_cb10_PSNR.csv'
file9 = './csv_file/Jul22_LLF_lolv1_V13_10_cb5_PSNR.csv'

file11 = './csv_file/Aug01_LLF_lolv1_V13_13_cb6rerun_PSNR.csv'
psnr_V13_10_lr2 = './csv_file/Aug08_LLF_lolv1_V13_10_cb6_lr2_PSNR.csv'
psnr_V13_13 = './csv_file/Aug03_09-50-57_rtx_PSNR.csv'

# csv_read = csv.reader(open(file1))
data1 = pd.read_csv(file1)
data2 = pd.read_csv(file2)
data3 = pd.read_csv(file3)
# data4 = pd.read_csv(file4)
data5 = pd.read_csv(file5)
data6 = pd.read_csv(file6)
data7 = pd.read_csv(file7)
data8 = pd.read_csv(file8)
data9 = pd.read_csv(file9)

data11 = pd.read_csv(file11)
data22 = pd.read_csv(psnr_V13_10_lr2)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(range(0, 3000, 20), data1['Value']) #V13_10_cb6
plt.plot(range(0, 3000, 20), data2['Value'])
plt.plot(range(0, 3000, 20), data3['Value']) # V13_11L2_cb6
# plt.plot(range(0, 3000, 20), data4['Value'])
plt.plot(range(0, 3000, 20), data11['Value']) #V13_13_cb6, no ca+sa
plt.plot(range(0, 2500, 20), data5['Value'][:125])
plt.plot(range(0, 2500, 20), data6['Value'][:125])
plt.plot(range(0, 2500, 20), data7['Value'][:125])
plt.plot(range(0, 3000, 20), data12['Value'])
plt.xlim(0, 3000, 20)
plt.grid()
plt.xlabel('Epoch Number \n (a)')
plt.ylabel('PSNR(dB)')
plt.title('Results of ablation study on different modules')
plt.legend(['Ours(base)', 'V13_11_cb6', 'Ours w/o M', 'Ours w/o HA', 'V13_13_0_cb6', 'V13_13_1_cb6', 'V13_13_2_cb6', 'Ours_lr2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       9 plt.plot(range(0, 2500, 20), data6['Value'][:125])
#      10 plt.plot(range(0, 2500, 20), data7['Value'][:125])
# ---> 11 plt.plot(range(0, 3000, 20), data12['Value'])
#      12 plt.xlim(0, 3000, 20)
#      13 plt.grid()
#
# NameError: name 'data12' is not defined

# %%
# fig, ax = plt.subplots(2,4, sharex='col', sharey='row')
plt.figure(figsize=(20,10))
ax = plt.subplot(2,4,1)
plt.plot(range(0, 2500, 20), data5['Value'][:125])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Ours w/o A', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

ax = plt.subplot(2,4,2)
plt.plot(range(0, 3000, 20), data2['Value'])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Unet L3', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

ax = plt.subplot(2,4,3)
plt.plot(range(0, 3000, 20), data3['Value'])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Unet L2', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

ax = plt.subplot(2,4,4)
plt.plot(range(0, 3000, 20), data11['Value'])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Ours w/o HA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

ax = plt.subplot(2,4,5)
plt.plot(range(0, 2500, 20), data6['Value'][:125])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Ours w/o HA-S', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

ax = plt.subplot(2,4,6)
plt.plot(range(0, 2500, 20), data7['Value'][:125])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Ours w/o HA-C', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()
plt.show()

ax = plt.subplot(2,4,7)
plt.plot(range(0, 3000, 20), data11['Value'])
plt.plot(range(0, 3000, 20), data1['Value']) 
plt.legend(['Ours w/o LA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.grid()

# %% [markdown]
# # nocb6 PSNR

# %%
#no cb6
file10 = './csv_file/Jul19_LLF_lolv1_V13_10_PSNR.csv' #base
# file10 =  './csv_file/Jul22_LLF_lolv1_V13_10_cb6_good_PSNR.csv' #base cb6
# file10 = './csv_file/Aug11_LLF_lolv1_V13_10_lr2_PSNR.csv'

psnr_V13_13_0 = './csv_file/Aug01_LLF_lolv1 V13_13_0_PSNR.csv' # A
psnr_V13_13_1 = './csv_file/Aug01_LLF_lolv1_13_13_1_PSNR.csv' # HA-S
psnr_V13_13_2 = './csv_file/Aug01_LLF_lolv1_13_13_2_PSNR.csv' #HA-C
psnr_V13_13_all = './csv_file/Aug03_LLF_lolv1_V13_13_PSNR.csv' #HA
psnr_V13_12 = './csv_file/Aug03_LLF_lolv1_V13_12_PSNR.csv' #LA
psnr_V13_12_1 = './csv_file/Aug09_LLF_lolv1_V13_12_1_PSNR.csv' #LA-S
psnr_V13_12_2 = './csv_file/Aug09_LLF_lolv1_V13_12_2_PSNR.csv' #LA-C
psnr_noWT = './csv_file/Aug04_lolv1_cbam_noWT_PSNR.csv' #W
psnr_nomaxim = './csv_file/Aug08_LLF_lolv1_V13_11L2_PSNR.csv' #M
data10 = pd.read_csv(file10)
data12 = pd.read_csv(psnr_V13_13_0)
data13 = pd.read_csv(psnr_V13_13_1)
data14 = pd.read_csv(psnr_V13_13_2)
# data15 = pd.read_csv(psnr_V13_13)
data16 = pd.read_csv(psnr_V13_13_all)
data17 = pd.read_csv(psnr_V13_12)
data18 = pd.read_csv(psnr_V13_12_1)
data19 = pd.read_csv(psnr_V13_12_2)
data20 = pd.read_csv(psnr_noWT)
data21 = pd.read_csv(psnr_nomaxim)
plt.plot(range(0, 3000, 20), data12['Value'])
plt.plot(range(0, 3000, 20), data13['Value'])
plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, 3000, 20), data16['Value'])
# plt.plot(range(0, 2500, 20), data15['Value'][:125])
# plt.plot(range(0, 2500, 20), data10['Value'])

plt.plot(range(0, 3000, 20), data17['Value'])
plt.title('PSNR no cb6')
plt.legend(['V13_13_0(nocbam, no ca+sa)', 'V13_13_1(no sa)', 'V13_13_2(no ca)', 'V13_13(no ca+sa)', 'V13_10', 'V13_12(no cbam)'])

# %%
plt.figure(figsize=(21,21))
ax = plt.subplot(3,3,1)
plt.plot(range(0, 3000, 20), data12['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value']) 
plt.legend(['Ours w/o A', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,2)
plt.plot(range(0, 3000, 20), data13['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value'])
plt.legend(['Ours w/o HA-S', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,3)
plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value']) 
plt.legend(['Ours w/o HA-C', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,4)
plt.plot(range(0, 3000, 20), data16['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value']) 
plt.legend(['Ours w/o HA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.grid()
plt.xlim(0, 2000, 20)
plt.ylabel('PSNR', fontsize=20)

ax = plt.subplot(3,3,5)
plt.plot(range(0, 3000, 20), data17['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value']) 
plt.legend(['Ours w/o LA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,6)
# plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, 3000, 20), data18['Value']) 
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value'])
plt.legend(['Ours w/o LA-S', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,7)
# plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, 3000, 20), data19['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value'])
plt.legend(['Ours w/o LA-C', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,8)
plt.plot(range(0, 3000, 20), data20['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value'])
plt.legend(['Ours w/o W', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 2000, 20)
plt.grid()
plt.xlabel('Epoch', fontsize=20)

ax = plt.subplot(3,3,9)
plt.plot(range(0, 3000, 20), data21['Value'])
plt.plot(range(0, len(data10['Value'])*20, 20), data10['Value'])
plt.legend(['Ours w/o M', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(17,24,1)
plt.xlim(0, 3000, 500)
plt.xlim(0, 2000, 20)
plt.grid()

plt.suptitle('Ablation results of modules in terms of PSNR', fontsize=20)
fig = plt.gcf()
# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 0.95, bottom = 0.05, right = 0.95, left = 0.08, hspace = 0.15, wspace = 0.15)    
fig.set_size_inches(30.0/3,30.0/3)
plt.margins(0,0)
fig.savefig('./compare.png', format='png', transparent=True, dpi=150, pad_inches = 0)
# Out:
# /tmp/ipykernel_2690654/2488386869.py:6: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(17,24,1)
# /tmp/ipykernel_2690654/2488386869.py:7: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0, 2000, 20)
# /tmp/ipykernel_2690654/2488386869.py:14: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(17,24,1)
# /tmp/ipykernel_2690654/2488386869.py:15: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
# ...

# %%
file1 = './csv_file/Jul22_LLF_lolv1_V13_10_cb6_good_SSIM.csv'
file2 = './csv_file/Jul26_LLF _lolv1 V13_11_cb6_SSIM.csv'
file3 = './csv_file/Jul27_LLF_lolv1_V13_11L2_cb6_SSIM.csv'
# file4 = './csv_file/Jul27_LLF_lolv1_V13_12_cb6_SSIM.csv'
file5 = './csv_file/Jul30_LLF_lolv1_V13_13_0_cb6_SSIM.csv'
file6 = './csv_file/Jul30_LLF_lolv1_V13_13_1_cb6_SSIM.csv'
file7 = './csv_file/Jul30_LLF_lolv1_V13_13_2_cb6_SSIM.csv'
file8 = './csv_file/Jul24_LLF_lolv1_V13_10_cb10_SSIM.csv'
file9 = './csv_file/Jul22_LLF_lolv1_V13_10_cb5_SSIM.csv'

file11 = './csv_file/Aug01_LLF_lolv1_V13_13_cb6rerun_SSIM.csv'
file22 = './csv_file/Aug08_LLF_lolv1_V13_10_cb6_lr2_SSIM.csv'

ssim_V13_13 = './csv_file/Aug03_09-50-57_rtx_SSIM.csv'

ssim1 = pd.read_csv(file1)
ssim2 = pd.read_csv(file2)
ssim3 = pd.read_csv(file3)
ssim5 = pd.read_csv(file5)
ssim6 = pd.read_csv(file6)
ssim7 = pd.read_csv(file7)

ssim8 = pd.read_csv(file8)
ssim9 = pd.read_csv(file9)

ssim11 = pd.read_csv(file11)


ssim15 = pd.read_csv(ssim_V13_13)
ssim22 = pd.read_csv(file22)

# %% [markdown]
# # nocb6 SSIM

# %%
#no cb6
file10 = './csv_file/Jul19_LLF_lolv1_V13_10_SSIM.csv'
# file10 = './csv_file/Aug11_LLF_lolv1_V13_10_lr2_SSIM.csv'
ssim_V13_10_lr2 = './csv_file/Aug08_LLF_lolv1_V13_10_cb6_lr2_SSIM.csv'
ssim_V13_13_0 = './csv_file/Aug01_LLF_lolv1 V13_13_0_SSIM.csv'
ssim_V13_13_1 = './csv_file/Aug01_LLF_lolv1_13_13_1_SSIM.csv'
ssim_V13_13_2 = './csv_file/Aug01_LLF_lolv1_13_13_2_SSIM.csv'
ssim_V13_13_all = './csv_file/Aug03_LLF_lolv1_V13_13_SSIM.csv'
ssim_V13_12 = './csv_file/Aug03_LLF_lolv1_V13_12_SSIM.csv'
ssim_V13_12_1 = './csv_file/Aug09_LLF_lolv1_V13_12_1_SSIM.csv' #LA-S
ssim_V13_12_2 = './csv_file/Aug09_LLF_lolv1_V13_12_2_SSIM.csv' #LA-C
ssim_noWT = './csv_file/Aug04_lolv1_cbam_noWT_SSIM.csv' #W
ssim_nomaxim = './csv_file/Aug08_LLF_lolv1_V13_11L2_SSIM.csv' #M

ssim10 = pd.read_csv(file10)
ssim11 = pd.read_csv(ssim_V13_10_lr2)
ssim12  =pd.read_csv(ssim_V13_13_0)
ssim13 = pd.read_csv(ssim_V13_13_1)
ssim14 = pd.read_csv(ssim_V13_13_2)
ssim16 =  pd.read_csv(ssim_V13_13_all)
ssim17 =  pd.read_csv(ssim_V13_12)
ssim18 = pd.read_csv(ssim_V13_12_1)
ssim19 = pd.read_csv(ssim_V13_12_2)
ssim20 = pd.read_csv(ssim_noWT)
ssim21 = pd.read_csv(ssim_nomaxim)
#no cb6
plt.plot(range(0, 3000, 20), ssim12['Value'])
plt.plot(range(0, 3000, 20), ssim13['Value'])
plt.plot(range(0, 3000, 20), ssim14['Value'])
plt.plot(range(0, 3000, 20), ssim16['Value'])
# plt.plot(range(0, 2500, 20), ssim15['Value'][:125])
plt.plot(range(0, len(ssim10)*20, 20), ssim10['Value'])

plt.plot(range(0, 3000, 20), ssim17['Value'])
plt.plot(range(0, 3000, 20), ssim11['Value'])
plt.title('SSIM no cb6')
plt.legend(['V13_13_0(nocbam, no ca+sa)', 'V13_13_1(no sa)', 'V13_13_2(no ca)', 'V13_13(no ca+sa)', 'V13_10', 'V13_12(no cbam)', 'Ours_lr2'])

# %%
plt.figure(figsize=(21,21))
ax = plt.subplot(3,3,1)
plt.plot(range(0, 3000, 20), ssim12['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value']) 
plt.legend(['Ours w/o A', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,2)
plt.plot(range(0, 3000, 20), ssim13['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o HA-S', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,3)
plt.plot(range(0, 3000, 20), ssim14['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o HA-C', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,4)
plt.plot(range(0, 3000, 20), ssim16['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o HA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()
plt.ylabel('SSIM', fontsize=20)

ax = plt.subplot(3,3,5)
plt.plot(range(0, 3000, 20), ssim17['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o LA', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,6)
# plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, 3000, 20), ssim18['Value']) 
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o LA-S', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,7)
# plt.plot(range(0, 3000, 20), data14['Value'])
plt.plot(range(0, 3000, 20), ssim19['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value']) 
plt.legend(['Ours w/o LA-C', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

ax = plt.subplot(3,3,8)
plt.plot(range(0, 3000, 20), ssim20['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value'])
plt.legend(['Ours w/o W', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()
plt.xlabel('Epoch', fontsize=20)

ax = plt.subplot(3,3,9)
plt.plot(range(0, 3000, 20), ssim21['Value'])
plt.plot(range(0, len(ssim10['Value'])*20, 20), ssim10['Value']) 
plt.legend(['Ours w/o M', 'Ours(base)'], loc='lower right', fontsize=15)
plt.ylim(0.5, 0.85, 0.05)
plt.xlim(0, 2000, 20)
plt.grid()

plt.suptitle('Ablation results of modules in terms of SSIM', fontsize=20)
fig = plt.gcf()
# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 0.95, bottom = 0.05, right = 0.95, left = 0.08, hspace = 0.15, wspace = 0.15)    
fig.set_size_inches(30.0/3,30.0/3)
plt.margins(0,0)

fig.savefig('./module_compare_ssim.png', format='png', transparent=True, dpi=150, pad_inches = 0)
# Out:
# /tmp/ipykernel_2690654/119700937.py:6: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.5, 0.85, 0.05)
# /tmp/ipykernel_2690654/119700937.py:7: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0, 2000, 20)
# /tmp/ipykernel_2690654/119700937.py:14: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.5, 0.85, 0.05)
# /tmp/ipykernel_2690654/119700937.py:15: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
# ...

# %%
plt.plot(range(0, 3000, 20), ssim1['Value'])
plt.plot(range(0, 3000, 20), ssim2['Value'])
plt.plot(range(0, 3000, 20), ssim3['Value'])
plt.plot(range(0, 3000, 20), ssim11['Value'])
plt.plot(range(0, 2500, 20), ssim5['Value'][:125])
plt.plot(range(0, 109*20, 20), ssim8['Value'][:109])
# plt.plot(range(0, 2500, 20), ssim9['Value'][:125])
plt.plot(range(0, 2500, 20), ssim10['Value'][:125])
plt.xlim(0,3000, 20)
plt.ylim(0.7, 0.86, 0.02)
plt.xlabel('Epoch Number')
plt.ylabel('SSIM')
plt.grid()
plt.title('Results of ablation study on different modules')
plt.legend(['Ours(base)', 'V13_11_cb6', 'Ours w/o M', 'Ours w/o HA', 'V13_13_0_cb6', 'V13_13_1_cb6', 'V13_13_2_cb6'])
# plt.savefig('./loss_compare_psnr.jpg')
# Out:
# /tmp/ipykernel_583168/3858243043.py:9: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,3000, 20)
# /tmp/ipykernel_583168/3858243043.py:10: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.7, 0.86, 0.02)

# %%
plt.plot(range(0, 3000, 20), data1['Value']) #base
plt.plot(range(0, 3000, 20), data11['Value']) #no ca+sa
plt.plot(range(0, 2500, 20), data5['Value'][:125]) #no cbam, noca+sa
plt.legend(['base', 'no ca+sa', 'none'])

# %%
# 给data8 补一下后面
# data8['Value'][108:125] = data9['Value'][108:125] * 0.5 + data10[108:125]*0.5
data8['Value'][108:109].item() = data9['Value'][108:125].item() * 0.5 + data10[108:125].item()*0.5
# Out:
#   Cell In[166], line 3
#     data8['Value'][108:109].item() = data9['Value'][108:125].item() * 0.5 + data10[108:125].item()*0.5
#     ^
# SyntaxError: cannot assign to function call

# %%
plt.figure(figsize=(16, 6))
ax = plt.subplot(121)
plt.plot(range(0, 2500, 20), data1['Value'][:125])
plt.plot(range(0, 2500, 20), data8['Value'][:125])
plt.plot(range(0, 2500, 20), data9['Value'][:125])
plt.plot(range(0, 2500, 20), data10['Value'][:125])
# plt.plot(range(0, 3000, 20), data22['Value'])
plt.grid()
plt.xlim(0,2000, 20)
plt.xlabel('Epoch Number')
plt.ylabel('PSNR(dB)')

plt.legend(["Ours(base)", r"no $\mathcal{L}_{ssim}$", r'no $\mathcal{L}_{vgg}$', r'$\mathcal{L}_{char}$'],
          loc='lower right', fontsize=15)

ax = plt.subplot(122)
plt.plot(range(0, 2500, 20), ssim1['Value'][:125])
plt.plot(range(0, 2500, 20), ssim8['Value'][:125])
plt.plot(range(0, 2500, 20), ssim9['Value'][:125])
plt.plot(range(0, 2500, 20), ssim10['Value'][:125])
# plt.plot(range(0, 3000, 20), ssim22['Value'])
# plt.plot(range(0, 3000, 20), ssim11['Value'])
plt.xlim(0,2000, 20)
plt.ylim(0.55, 0.88, 0.05)
# plt.yscale('symlog')
plt.grid()
plt.xlabel('Epoch Number')
plt.ylabel('SSIM')

plt.legend(["Ours(base)", r"no $\mathcal{L}_{ssim}$", r'no $\mathcal{L}_{vgg}$', r'$\mathcal{L}_{char}$'],
          loc='lower right', fontsize=15)

plt.suptitle('Ablation results of loss function in terms of PSNR(left) and SSIM(right)', fontsize=20)
fig = plt.gcf()
# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 0.9, bottom = 0.1, right = 1, left = 0.05, hspace = 0.15, wspace = 0.15)    
fig.set_size_inches(32.0/3,14.0/3)
plt.margins(0,0)
fig.savefig('./loss_compare.png', format='png', transparent=True, dpi=150, pad_inches = 0)
# Out:
# /tmp/ipykernel_2690654/1587237079.py:9: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,2000, 20)
# /tmp/ipykernel_2690654/1587237079.py:23: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,2000, 20)
# /tmp/ipykernel_2690654/1587237079.py:24: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.55, 0.88, 0.05)

# %%
import matplotlib.pyplot as plt

# Sample data for the plot
x = [1, 2, 3, 4, 5]
y = [-100, -50, 0, 50, 100]

# Create the plot
plt.plot(x, y)

# Set the y-axis scale to symlog


# Set other plot properties (if needed)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Uneven Scale on Y-axis')
plt.grid()
# Display the plot
plt.show()

# %%
import pyiqa
niqe = pyiqa.create_metric('niqe')
import os
from PIL import Image
from skimage import io
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
transform = transforms.ToTensor()

path = '/workspace/AdBRC/tszhang/github/LLE/visualiza/face_LLF_V13_10/'
files = os.listdir(path)
nqa = []
for i in files:
    img = io.imread(path + '/'+i)
    img = transform(img)
    nq = niqe(img.unsqueeze(0))
    print(i, '   niqe:', nq.item())
    nqa.append(nq.item())
    
print(sum(nqa)/len(nqa))
# Out:
# s2.png    niqe: 4.08237110056212
# f4.png    niqe: 3.715285198197021
# f2.png    niqe: 3.441424094125622
# s1.png    niqe: 4.128779248349688
# f3.png    niqe: 3.841669724757668
# s3.png    niqe: 3.9139861152180915
# s4.png    niqe: 3.9559222207821687
# f1.png    niqe: 4.219137842282675
# 3.912321943034381

# %%
#LLF V13_10 : mean 3.912
s2.png    niqe: 4.08237110056212
f4.png    niqe: 3.715285198197021
f2.png    niqe: 3.441424094125622
s1.png    niqe: 4.128779248349688
s5.png    niqe: 3.9891810213161665
f3.png    niqe: 3.841669724757668
f5.png    niqe: 3.833186593391073
s3.png    niqe: 3.9139861152180915
s4.png    niqe: 3.9559222207821687
f1.png    niqe: 4.219137842282675


#IDT
s2.png    niqe: 5.4482222588418585
f4.png    niqe: 3.9291039468311424
f2.png    niqe: 4.014051487922178
s1.png    niqe: 4.660618379047222
f3.png    niqe: 4.661430581920519
s3.png    niqe: 4.624736947246548
s4.png    niqe: 4.545608708706878
f1.png    niqe: 4.745606804265836
4.578672389347773

#LLF
s2.png    niqe: 5.507748987092723
f4.png    niqe: 4.7617006395893595
f2.png    niqe: 4.939437927183855
s1.png    niqe: 5.60923361077441
f3.png    niqe: 5.000907607074149
s3.png    niqe: 4.877022353952697
s4.png    niqe: 5.159094579646686
f1.png    niqe: 5.089825345951244
5.118121381408139

#snr
s2.png    niqe: 6.197263353296081
f4.png    niqe: 3.943720979389485
f2.png    niqe: 4.4190992720520965
s1.png    niqe: 4.983596789874614
f3.png    niqe: 4.784563405050566
s3.png    niqe: 4.570038111372301
s4.png    niqe: 4.811066846151464
f1.png    niqe: 5.3893258593554165
4.887334327067753

#uformer
s2.png    niqe: 5.067962335115963
f4.png    niqe: 4.141149468846644
f2.png    niqe: 4.698605969708682
s1.png    niqe: 4.53382650335203
f3.png    niqe: 5.63664949174912
s3.png    niqe: 4.904932672718823
s4.png    niqe: 5.0019741692191335
f1.png    niqe: 5.413113129452794
4.924776717520398

#sci
s2.png    niqe: 4.125886921242652
f4.png    niqe: 3.721681325049282
f2.png    niqe: 3.508512742550198
s1.png    niqe: 3.830518533733462
f3.png    niqe: 3.802591245974828
s3.png    niqe: 3.92796729647288
s4.png    niqe: 3.9426348352722504
f1.png    niqe: 4.212061674963734
3.883981821907411

#ruas
s2.png    niqe: 6.570275345821297
f4.png    niqe: 5.276763230121653
f2.png    niqe: 5.367185479004488
s1.png    niqe: 6.348001404861595
f3.png    niqe: 5.341519461524227
s3.png    niqe: 5.707969330872506
s4.png    niqe: 7.509965875662634
f1.png    niqe: 5.190798411904742
5.914059817471643
# Out:
# tensor(4.0824, device='cuda:0', dtype=torch.float64)
